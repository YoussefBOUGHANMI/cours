# %%
import pandas as pd

# %%
"Equipe 1", "Equipe 2" ,"FratésPleins" , "Equipe 4" , "Los Tiburòn de l'Apentencia"

# %%
tab = [["Equipe 1" , ["Esteban REIG" , "Marine Pinault" , "Solène Castaner"] , 0 , 0],
       ["Equipe 2" , ["Wenissa AIT-RADI" , "Soumaya RIAHI" , "Amal LAAGUIDI" , "Leila TAHYRY"] , 0 , 0],
       ["FratésPleins" , ["Maël ARFOSEA" , "Victor PONCET" , "Yanis ERDALI"] , 0 , 0],
       ["Equipe 4" , ["Maya JEAN" , "Fayssal" , "Steve" , "Emma FOUSSARD"] , 0 , 0],
       ["Los Tiburòn de l'Apentencia" , ["Juliette" , "Jules" , "Maxime"]  , 0 , 0]]
team = pd.DataFrame(tab , columns=["nom" , "participants" , "benef" , "essaie"])

# %%
team
# Out:
#                            nom  \
# 0                     Equipe 1
# 1                     Equipe 2
# 2                 FratésPleins
# 3                     Equipe 4
# 4  Los Tiburòn de l'Apentencia
#
#                                         participants  benef  essaie
# 0    [Esteban REIG, Marine Pinault, Solène Castaner]      0       0
# 1  [Wenissa AIT-RADI, Soumaya RIAHI, Amal LAAGUID...      0       0
# 2        [Maël ARFOSEA, Victor PONCET, Yanis ERDALI]      0       0
# 3         [Maya JEAN, Fayssal, Steve, Emma FOUSSARD]      0       0
# 4                          [Juliette, Jules, Maxime]      0       0

# %%
# !pip install google-api-python-client
# Out:
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.166.0-py2.py3-none-any.whl (13.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 4.4 MB/s eta 0:00:0000:0100:01
# Collecting uritemplate<5,>=3.0.1
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0
#   Downloading google_auth-2.38.0-py2.py3-none-any.whl (210 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.8/210.8 kB 5.9 MB/s eta 0:00:00
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5
#   Downloading google_api_core-2.24.2-py3-none-any.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.1/160.1 kB 7.7 MB/s eta 0:00:00
# Collecting google-auth-httplib2<1.0.0,>=0.2.0
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Collecting httplib2<1.0.0,>=0.19.0
#   Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /Users/youssefboughanmi/opt/anaconda3/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (4.25.3)
# Collecting proto-plus<2.0.0,>=1.22.3
#   Downloading proto_plus-1.26.1-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /Users/youssefboughanmi/opt/anaconda3/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.31.0)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2
#   Downloading googleapis_common_protos-1.69.2-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.2/293.2 kB 7.3 MB/s eta 0:00:0000:01
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/youssefboughanmi/opt/anaconda3/lib/python3.9/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/youssefboughanmi/opt/anaconda3/lib/python3.9/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (5.3.3)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/youssefboughanmi/opt/anaconda3/lib/python3.9/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/youssefboughanmi/opt/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/youssefboughanmi/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/youssefboughanmi/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2022.9.24)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/youssefboughanmi/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/youssefboughanmi/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.3)
# Installing collected packages: uritemplate, rsa, proto-plus, httplib2, googleapis-common-protos, google-auth, google-auth-httplib2, google-api-core, google-api-python-client
# Successfully installed google-api-core-2.24.2 google-api-python-client-2.166.0 google-auth-2.38.0 google-auth-httplib2-0.2.0 googleapis-common-protos-1.69.2 httplib2-0.22.0 proto-plus-1.26.1 rsa-4.9 uritemplate-4.1.1

# %%
from googleapiclient.discovery import build
import re

def get_video_id(youtube_url):
    """Extrait l'ID de la vidéo à partir d'un lien YouTube."""
    regex = r"(?:v=|youtu\.be/)([a-zA-Z0-9_-]{11})"
    match = re.search(regex, youtube_url)
    return match.group(1) if match else None

def get_comments(video_url, api_key, max_comments=100):
    video_id = get_video_id(video_url)
    if not video_id:
        print("Lien invalide.")
        return

    youtube = build('youtube', 'v3', developerKey=api_key)

    comments = []
    next_page_token = None

    while len(comments) < max_comments:
        request = youtube.commentThreads().list(
            part='snippet',
            videoId=video_id,
            pageToken=next_page_token,
            maxResults=min(100, max_comments - len(comments)),
            textFormat='plainText'
        )
        response = request.execute()

        for item in response.get('items', []):
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            comments.append(comment)

        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

    return comments

# Exemple d'utilisation
if __name__ == "__main__":
    api_key = "AIzaSyCAtBg_PJVw3AjV4Vx6b2uFPqWCrrhxOdE"
    video_url = "https://www.youtube.com/watch?v=dQw4w9WgXcQ"  # Remplace par ton lien
    commentaires = get_comments(video_url, api_key, max_comments=50)

    for i, commentaire in enumerate(commentaires, 1):
        print(f"{i}. {commentaire}\n")
# Out:
# 1. 1 BILLION views for Never Gonna Give You Up!  Amazing, crazy, wonderful! Rick ♥️
#
# 2. Nubbin brought me here
#
# 3. banger
#
# 4. what a iconic song
#
# 5. The YouTube algorithm just Rick rolled me 😂
#
# 6. 0:44
#
# 7. i watched Steve singing lava chicken song and after the video ended this pops up
#
# 8. AAAAA H1T1 GOT ME
#
# 9. The only one that’s this song
#
# 10. Chrono trigger Robo's theme 🤣
#
# 11. ну и где мое объяснение в игрееееее
#
# 12. So... I came here for a ruler of my heart ivan cover..
#
# 13. The audio and video of his voice and face don't match :)
#
# 14. The fact that this song still hits is crazy
#
# 15. 🥰🥰🥰🥰🥰🥰🥰👌👌👌👌👌👍👍👍👍👍👍👍
#
# 16. Who's here on April 2025?🎉
#
# 17. This was a QR code in my school bathroom
#
# 18. Bro, I love Rick
#
# 19. Molly and Brad was here ❤💪🤭🫶🖕❤️
#
# 20. I didn't get rickrolled today, I just really enjoy this song
#
# 21. Who were here due to chatgpt lol😂
#
# 22. this is the only song i like
#
# 23. These who watched the video till the end here 👇
#
# 24. I think I just got Rick rolled.
#
# 25. Me
#
# 26. Estaba descargo un juego y un hdp me mando un link que no era :v
#
# 27. Juda zoʻr🎉🎉❤
#
# 28. 2025 de izleyenler TÜRKLER BURDAMI!!!!!!🇹🇷🇹🇷🇹🇷🇹🇷🇹🇷🐺🐺
#
# 29. Anyone that got Rick rolled by their recommendations?
#
# 30. Did YouTube recommendations just rick roll me?
#
# 31. The 80s must have been a time to be alive
#
# 32. you are the a very nice good person and you deserve to it i love your art so very so very so🎉
#
# 33. That riff sound futuristic and nostalgic at the same time!
#
# 34. OMG this is very popular video! And popular meme song!
#
# 35. I want a man who will never giveup on me. Anda be by my side
#
# 36. You know the rules and so do i😉
#
# 37. It's the final brain cell
#
# 38. Never Going To Give you up
#
# 39. Day 1299 of getting Rickrolled Everyday
#
# 40. God damn you Black Mirror 🤣
#
# 41. Este hombre merece un Óscar,como no olvidar 1989😢
#
# 42. Damn nubbing 🥲
#
# 43. I scanned a QR code in the big 2025 💔
#
# 44. Ye very original
#
# 45. 9 April of 2025. A friend was rickrolled
#
# 46. Круто
#
# 47. hey !!
#
# 48. 2027 anyone.
#
# 49. 2025?
#
# 50. I find link by gpt now this what i got
